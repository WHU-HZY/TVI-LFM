# %%
import numpy as np
list = np.load("/data1/hzy_data/SYSU-MM01/train_text_eaaug_list.npy")
print(len(list))
# Out:
# 22258

# %%
list[0]
# Out:
# array(['a boy with short shameful hair sleeve polish - neck fume grey t - with a red computer paired cream cargo capri followed by black sandals, holding a mobile phone in his right.',
#        'a with black wearing one half sleeves - smoke grey t - shirt with a graphic paired with capri followed a twain of black sandals, hold a headphone in his proper hand.',
#        'a son black wearing sleeves round - neck smoke grey t - with a red computer graphic paired cream load capri followed by a of black sandals, holding roving phone his right.',
#        'son with short wearing half round - neck smoke gray triiodothyronine - with a computer graphic with cargo capri followed by a pair of fateful sandals, hold a telephone set in his helping hand.',
#        'boy short black whisker wearing half sleeve round out - smoke grey - shirt with a red computer graphic paired with cream cargo capri followed by a yoke of black, his right hand.'],
#       dtype='<U319')

# %%
np.random.choice(list[0],1)[0]
# Out:
# 'Young man a sleek hairstyle, a voguish that consists a grey round - neck tonne - shirt have a bold graphic design, paired with cream - colour cargo capris. Helium completes his look with of sandals, and a mobile phone in his right hand.'

# %%
import json
with open("/data1/hzy_data/SYSU-MM01/Text/Blip_IR/caption_dict_Blip_IR.json", "r") as f:
    caption_dict = json.load(f)
print(len(caption_dict))
# Out:
# 15792

# %%
import torch
a = torch.load("/data1/hzy_log/WORK_2024_LOG/logs/Baseline_train[RGB_IR_Text]_Blip_wo_color_add_LLM_0.5_id,wrt_2024-03-16-18:09:25/checkpoint/checkpoint_latest.pth")

# %%
print(a['model_state_dict'])
# Out:
# OrderedDict([('logit_scale', tensor(2.6593, device='cuda:3')), ('base_model.positional_embedding', tensor([[-4.2090e-03, -1.6867e-04,  5.1541e-04,  ..., -7.3320e-04,
#           1.2923e-03, -2.5006e-04],
#         [-1.1862e-03,  5.3247e-03, -2.6412e-03,  ..., -7.1328e-03,
#           5.8542e-04,  2.2848e-03],
#         [-1.8793e-03, -2.3636e-03, -7.5387e-03,  ..., -1.6093e-04,
#           2.2027e-03,  2.5691e-03],
#         ...,
#         [-1.0544e-04,  6.1446e-05,  2.6020e-04,  ..., -3.1106e-04,
#          -3.8636e-06,  8.4668e-05],
#         [-1.1666e-04,  6.9272e-06,  1.6946e-04,  ..., -1.1274e-06,
#          -1.0321e-05,  1.8751e-04],
#         [ 1.0729e-04, -2.6943e-04,  2.7233e-04,  ..., -5.1767e-04,
#          -2.2766e-04,  1.0874e-04]], device='cuda:3')), ('base_model.text_projection', tensor([[-4.1882e-06, -6.9406e-42,  7.0891e-06,  ...,  8.0218e-08,
#           9.3340e-42,  3.1795e-42],
#         [-7.1256e-42, -7.7282e-42,  1.1335e-41,  ...,  1.2820e-41,
# ...
